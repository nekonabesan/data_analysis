# %%
import os
from dotenv import load_dotenv
from pathlib import Path
import datetime

import pandas as pd
import pandas_datareader.data as pdr
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
from pathlib import Path
import sys

sys.path.append('/home/jovyan/notebook/Modules')
from get_market_data import GetMarketData

gmd = GetMarketData(Path('/home/jovyan/data/data-main'))
df_9434 = gmd.get_data_from_yfinance(
    tickers=['9434.T'],
    start='2025-01-01',
    end='2025-03-31'
 )

df_9434.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker          9434.T      9434.T      9434.T      9434.T    9434.T
# Date
# 2025-01-06  184.993484  188.953587  184.522043  188.576440  79616700
# 2025-01-07  185.842102  185.842102  183.956338  184.993499  56739500
# 2025-01-08  183.673462  185.747800  183.107727  185.747800  63507500
# 2025-01-09  183.579163  184.993486  183.202015  184.804912  56300000
# 2025-01-10  181.976273  183.767743  181.976273  182.919155  53731800
